# %% [markdown]
# Author: Yu Hamakawa
#
# Created: September 9, 2024

# %% [markdown]
# # Visualization
#
# In this tutorial, you can follow the visualization process used in the analysis.
#
# ---

# %%
from pathlib import Path

BASE_DIR = Path.cwd().parent
DATA_DIR = BASE_DIR / 'data'
PLOT_DIR = BASE_DIR / 'src' / 'visualization'

# %% [markdown]
# ## About Figure 1
#
# RMSD is calculated by OpenEye toolkit, so could not released.

# %% [markdown]
# ## Make Figure 2 & Figure S1, S2
#
# The figure 2 and the figure S1, S2 in the paper are made by the code below

# %%
FILE_PATH = PLOT_DIR / 'plot_props.py'
# %run $FILE_PATH

# %% [markdown]
# ## Make Figure 4 & Figure S3
#
# The figure 4 and the figure S3 in the paper are made by the code below

# %%
FILE_PATH = PLOT_DIR / 'ecfp_distance.py'
# %run $FILE_PATH

# %% [markdown]
# ## Make Figure S4
#
# The figure S4 in the paper is made by the code below

# %%
FILE_PATH = PLOT_DIR / 'plot_scatter.py'
# %run $FILE_PATH

# %% [markdown]
# ## Make Figure S5 to S63
#
# The figure S5 to S63 in the paper are made by the code below

# %%
FILE_PATH = PLOT_DIR / 'violin_testing.py'
# %run $FILE_PATH
FILE_PATH = PLOT_DIR / 'testing4table.py'
# %run $FILE_PATH
